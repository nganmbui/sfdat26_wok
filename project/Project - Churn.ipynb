# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_csv('/Users/Nganbui/Documents/datascience/churn_data_7days.csv', sep = ',', index_col=0)

# %%
churn = data[data.duration==1]
churn.drop(['duration'], axis= 1,inplace=True)
churn.head()
# Out:
# /anaconda/envs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       subscriptioneventdate  iswinback  gender  cancel_30  i_fr_7d_after_sub  \
# index
# 2              1/7/16 11:17        1.0     0.0        1.0                0.0
# 4             1/10/16 11:16        0.0     0.0        1.0                1.0
# 6             12/29/15 5:52        0.0     0.0        1.0                0.0
# 9            12/31/15 14:35        1.0     0.0        0.0                0.0
# 10             1/12/16 2:37        1.0     0.0        0.0                0.0
#
#        i_pv_7d_after_sub  o_fr_7d_after_sub  o_pv_7d_after_sub  i_messages_7d  \
# index
# ...

# %%
churn.isnull().sum()
# Out:
# subscriptioneventdate    0
# iswinback                0
# gender                   0
# cancel_30                0
# i_fr_7d_after_sub        0
# i_pv_7d_after_sub        0
# o_fr_7d_after_sub        0
# o_pv_7d_after_sub        0
# i_messages_7d            0
# o_messages_7d            0
# o_carousel               0
# o_smartpick              0
# dtype: int64

# %%
churn.corr()
#Sadly it seems like there are weak correlations all around
# Out:
#                    iswinback    gender  cancel_30  i_fr_7d_after_sub  \
# iswinback           1.000000 -0.015050   0.007191          -0.038560
# gender             -0.015050  1.000000   0.104864           0.404807
# cancel_30           0.007191  0.104864   1.000000           0.039461
# i_fr_7d_after_sub  -0.038560  0.404807   0.039461           1.000000
# i_pv_7d_after_sub  -0.018226  0.490119   0.044173           0.838930
# o_fr_7d_after_sub  -0.029680 -0.136899  -0.026100          -0.039620
# o_pv_7d_after_sub  -0.033371 -0.189126  -0.021393           0.041672
# i_messages_7d       0.006884  0.328365   0.035506           0.656749
# o_messages_7d      -0.010608 -0.021075  -0.008506           0.203503
# o_carousel         -0.030018 -0.180705  -0.032792          -0.063123
# o_smartpick        -0.128215 -0.228891  -0.049192           0.020301
#
#                    i_pv_7d_after_sub  o_fr_7d_after_sub  o_pv_7d_after_sub  \
# ...
